# %% [markdown]
# # Introduction to Matplotlib

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4]);

# %%
x = [1,2,3,4]
y=[11,22,33,44]
plt.plot(x,y);

# %%
# stateless way of plotting (pyplot API)

# %%
# 1st method
fig = plt.figure() # creates a figure
ax = fig.add_subplot() # adds some axes
plt.show()

# %%
# 2nd method
fig = plt.figure() # creates a figure
ax = fig.add_axes([1,1,1,1,])
ax.plot(x,y)
plt.show()

# %%
# 3rd method (Recommended)
fig, ax = plt.subplots()
ax.plot(x,y); # add some data and semicolon at end
# instead of plot.show()

# %%
# 3rd method (Recommended)
fig, ax = plt.subplots()
ax.plot(x,[50, 100, 200, 250]); # add some data and semicolon at end
# instead of plot.show()
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# <img src="images/anatomy-of-matplotlib-figure.png" />

# %%
# <img src="imagename.png"/> # Markdown

# %% [markdown]
# # Matplotlib example workflow

# %%
# 0. import matplotlib and get it redy for plotting
# in jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data # created data
x = [1,2,3,4]
y = [11,22,33,44]

# 2. Setup plot # size 10 x 10
fig, ax = plt.subplots(figsize=(10,10))

# 3. PLot the data
ax.plot(x,y) # adding data to axes

# 4. Customize plot
ax.set(title="Simplt Plot",
      xlabel="x-axis",
      ylabel="y-axis")
# 5. SAve and show (you sve the whole figure)
fig.savefig("./images/sample-plot.png")

# %% [markdown]
# # Scatter and Bar Plot

# %% [markdown]
# # Making figures with NumPy arrays
#
# We want:
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * subplot

# %%
import numpy as np

# %%
# create some data
x = np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot the data and create a line plot
fig, ax = plt.subplots()
ax.plot(x, x **2)

# %%
# USe the same data and create a scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# Make a plot from a dictionary
nut_butter_prices = {"Almond butter": 10,
                    "Peanut butter": 8,
                    "Cashew butter": 12}

fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax.set(title="Dan's Nut Butter Store", ylabel=" Price ($)");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
# Make some data for histograms and plot it 
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Two options for subplots

# %%
# Subplots option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                            ncols=2,
                                            figsize=(10,5))
# plot to each diff axis
ax1.plot(x, x/2);
ax1.set(title="Axis 1")

ax2.scatter(np.random.random(10), np.random.random(10));
ax2.set(title="Axis 2")

ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());

ax4.hist(np.random.randn(100));

# %%
# Subplots option 2
fig, ax = plt.subplots(nrows=2, 
                      ncols=2,
                      figsize=(10,5))
# Plot to each different index
ax[0,0].plot(x, x/2);

ax[0,1].scatter(np.random.random(10), np.random.random(10));

ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values())

ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from pandas DataFrames

# %%
import pandas as pd

# %%
# Make a DataFrame
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range("1/1/2020", periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
# Remove last two zeros from prices
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors     Price
# 0  Toyota  White         150043      4   $4,000.
# 1   Honda    Red          87899      4   $5,000.
# 2  Toyota   Blue          32549      3   $7,000.
# 3     BMW  Black          11179      5  $22,000.
# 4  Nissan  White         213095      4   $3,500.
# 5  Toyota  Green          99213      4   $4,500.
# 6   Honda   Blue          45698      4   $7,500.
# 7   Honda   Blue          54738      4   $7,000.
# 8  Toyota  White          60000      4   $6,250.
# 9  Nissan  White          31600      4   $9,700.

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
type(car_sales)
# Out:
# pandas.core.frame.DataFrame

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2020", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
# Let's plot the total sales
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
# Reassign price column to int
car_sales["Price"] = car_sales["Price"].astype(int)

# Plot scatter plot with price column as numeric
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
# How about a bar graph?

x = np.random.rand(10, 4)
x

# Turn it into a DataFrame
df = pd.DataFrame(x, columns=["a","b","c","d"])
df
# Out:
#           a         b         c         d
# 0  0.082695  0.765662  0.453940  0.314331
# 1  0.636173  0.905660  0.525451  0.494658
# 2  0.227486  0.322829  0.209896  0.611883
# 3  0.232268  0.921204  0.213017  0.240088
# 4  0.780857  0.309290  0.348525  0.838849
# 5  0.722075  0.701893  0.367845  0.535854
# 6  0.377907  0.583833  0.817759  0.110635
# 7  0.570529  0.023736  0.169411  0.134922
# 8  0.167634  0.550930  0.670716  0.864277
# 9  0.915972  0.906474  0.176480  0.002329

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot();

# %%
car_sales.plot(x="Make",y="Odometer (KM)", kind="bar");

# %%
# How about histograms? great for visualizing distributions
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=20);

# %%
# 10 for the number of bins fits this graph most

# %%
# Let's try on another data set
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Create a histrogram
heart_disease["age"].plot.hist(bins=50);

# %%
heart_disease["age"].plot.hist();

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist();

# %%
heart_disease.plot.hist(figsize=(10, 30), subplots=True);

# %% [markdown]
# ### Which one should you use? Pyplot vs matplotlib OO method
# *  When plotting something quickly , okay to use pyplot method
# *  When plotting something more advanced, use the OO method

# %%
over_50 = heart_disease[heart_disease["age"] >50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
# Pyplot method (plotting directly from a pandas df)
over_50.plot(kind="scatter", 
            x="age",
            y='chol',
            c='target');

# %%
# OO method
fig, ax = plt.subplots(figsize=(10,6))
over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target",
            ax=ax);

ax.set_xlim([45,100])
# Out:
# (45.0, 100.0)

# %%
## OO method from scratch with customization
fig, ax = plt.subplots(figsize=(10,6))

# Plot the data
scatter = ax.scatter(x=over_50["age"],
                     y=over_50["chol"], 
                    c=over_50["target"]);

# Customize
ax.set(title="Heart Disease and Chol Levels",
      xlabel="Age",
      ylabel="Cholesterol");

# Add legend
ax.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line
ax.axhline(over_50["chol"].mean(), linestyle="dashed");

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1, 
                              figsize=(10,10))
# Add data to axis o ax0
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50['target'])

# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
       ylabel="Cholesterol")

# Add legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")

# Add a mean line
ax0.axhline(y=over_50["chol"].mean(), linestyle="--");


# Subplot of thalach, age

#Add Data to axis 1 ax1
scatter2 = ax1.scatter(x=over_50["age"],
                      y=over_50['thalach'],
                      c=over_50['target'])

ax1.set(title="Heart Disease and Thalach", 
       xlabel="Age",
       ylabel="Max Heart Rate")

# Add legend to ax1
ax1.legend(*scatter2.legend_elements(), title="Target")

# Add a mean line
ax1.axhline(y=over_50["thalach"].mean(), linestyle="--");

# %% [markdown]
# # Customizing Matplotlib plots and getting stylish

# %%
# Style of plot is customizable
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-whitegrid')
car_sales["Price"].plot();

# %%
plt.style.use('seaborn')
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer (KM)", 
              y="Price",
              kind="scatter");

# %%
plt.style.use('ggplot')
car_sales["Price"].plot();

# %%
# Create some data
x = np.random.randn(10,4)
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0 -0.406189 -1.422854 -1.314361 -0.554286
# 1 -0.648113  1.147721 -0.720673  2.827535
# 2 -0.419437  0.853880  0.771019 -0.387741
# 3  0.602751 -0.551914 -0.235882 -0.124891
# 4  0.681945 -0.720679  0.767009  1.503409
# 5 -0.480813 -0.649889  1.767744 -0.770113
# 6  0.526039  0.532380 -0.228484  0.797680
# 7 -1.151355  1.025227  0.770502 -0.009688
# 8  1.656716 -0.774486 -0.769543 -0.378379
# 9  0.174972  1.010769  0.686481 -0.272360

# %%
ax = df.plot(kind='bar')
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
# Customize our plot with set method
ax = df.plot(kind='bar')
# Add labels and title
ax.set(title="Random Bar Graph from DataFrame", 
       xlabel="Row Number",
       ylabel="Random Number")
# Make legend visible
ax.legend().set_visible(True)

# %%
# Set the style
plt.style.use('seaborn-whitegrid')


## OO method from scratch with customization
fig, ax = plt.subplots(figsize=(10,6))

# Plot the data
scatter = ax.scatter(x=over_50["age"],
                     y=over_50["chol"], 
                     c=over_50["target"], 
                     cmap='winter');

# cmap="winter" changes the color map

# Customize
ax.set(title="Heart Disease and Chol Levels",
      xlabel="Age",
      ylabel="Cholesterol");

# Add legend
ax.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line
ax.axhline(over_50["chol"].mean(), linestyle="dashed");

# %%
# Customizing the y and x axis limitations

# %%
# Subplot of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1, 
                              figsize=(10,10))
# Add data to axis o ax0
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50['target'], 
                     cmap='winter')

# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
       ylabel="Cholesterol")

# Add legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")

# Add a mean line
ax0.axhline(y=over_50["chol"].mean(), linestyle="--");

# Change the x-axis limits
ax0.set_xlim([50,80])

# Subplot of thalach, age

#Add Data to axis 1 ax1
scatter2 = ax1.scatter(x=over_50["age"],
                      y=over_50['thalach'],
                      c=over_50['target'],
                      cmap='winter')

ax1.set(title="Heart Disease and Thalach", 
       xlabel="Age",
       ylabel="Max Heart Rate")

# Add legend to ax1
ax1.legend(*scatter2.legend_elements(), title="Target")

# Add a mean line
ax1.axhline(y=over_50["thalach"].mean(), linestyle="--");

# Change the x-axis limits
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])


# Add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %%
fig.savefig("heart-disease-analysis-save-with-code.png")
